# %%
import logRegres

# %% [markdown]
# 目标函数的偏导公式为：
# ![](http://windmissing.github.io/images/2019/164.jpg)
# 公式推导详见：https://windmising.gitbook.io/liu-yu-bo-play-with-machine-learning/9-1/9-3

# %%
dataArr,labelMat=logRegres.loadDataSet()
logRegres.gradAscent(dataArr,labelMat)
# Out:
# matrix([[ 4.12414349],
#         [ 0.48007329],
#         [-0.6168482 ]])

# %%
logRegres.plotBestFit(logRegres.gradAscent)

# %% [markdown]
# 随机梯度下降法求偏导的公式：
# ![](http://windmissing.github.io/images/2019/82.png)
# 推导过程见：https://windmising.gitbook.io/liu-yu-bo-play-with-machine-learning/6-1/6-6

# %%
dataArr,labelMat=logRegres.loadDataSet()
logRegres.stocGradAscent0(dataArr,labelMat)
# Out:
# matrix([[ 1.01702007],
#         [ 0.85914348],
#         [-0.36579921]])

# %%
logRegres.plotBestFit(logRegres.stocGradAscent0)

# %%
dataArr,labelMat=logRegres.loadDataSet()
logRegres.plotBestFit(logRegres.stocGradAscent1)

# %%
def classsifyVector(inX, weights):
    h = logRegres.sigmoid(np.array(inX) * np.array(weights))
    return h > 0.5

# %%
def colicTest():
    trainData = []
    trainLabel = []
    for line in open('horseColicTraining.txt').readlines():
        dataList = [float(data) for data in line.strip().split('\t')]
        trainData.append(dataList[0:-1])
        trainLabel.append(dataList[-1])
    trainWeights = logRegres.stocGradAscent1(trainData, trainLabel, 500)
    
    error, total = 0, 0
    for line in open('horseColicTest.txt').readlines():
        total += 1
        dataList = [float(data) for data in line.strip().split('\t')]
        testData.dataList[0:-1]
        testLabel.dataList[-1]
        y = classifyVector(testData, trainWeights)
        if y != testLabel:
            error += 1
    return error / total
    
colicTest()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-bef0eb124b51> in <module>
#      19     return error / total
#      20
# ---> 21 colicTest()
#
# <ipython-input-9-bef0eb124b51> in colicTest()
#       2     trainData = []
#       3     trainLabel = []
# ----> 4     for line in open('horseColicTraining.txt').readlines():
#       5         dataList = [float(data) for data in line.strip().split('\t')]
#       6         trainData.append(dataList[0:-1])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'horseColicTraining.txt'
